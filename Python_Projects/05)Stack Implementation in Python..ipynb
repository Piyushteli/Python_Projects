# %% [markdown]
# # "Stack Implementation in Python"

# %%
l=[]
while True:
    print(f"!!!Menu!!!\n1)push \n2)pop \n3)last \n4)Display \n5)Exit ")
    choice=(int(input("Enter the Choice: ")))
    if choice==1:
        n=input("Enter the Element: ")
        l.append(n)
        print(l)
    elif choice==2:
        if len(l)==0:
            print("Stack is Empty")
        else:
            print(l.pop())
            print(l)
    elif choice==3:
        print(l[-1])
    elif choice==4:
        print("ELEMENT OF STACK :",l)
    elif choice==5:
        break
    else:
        print("Invalid choice")
# Out:
# !!!Menu!!!
# 1)push
# 2)pop
# 3)last
# 4)Display
# 5)Exit
# Enter the Choice: 1
# Enter the Element: 10
# ['10']
# !!!Menu!!!
# 1)push
# 2)pop
# 3)last
# 4)Display
# 5)Exit
# Enter the Choice: 1
# Enter the Element: 20
# ['10', '20']
# !!!Menu!!!
# 1)push
# 2)pop
# 3)last
# 4)Display
# 5)Exit
# Enter the Choice: 1
# Enter the Element: 30
# ['10', '20', '30']
# !!!Menu!!!
# 1)push
# 2)pop
# 3)last
# 4)Display
# 5)Exit
# Enter the Choice: 1
# Enter the Element: 40
# ['10', '20', '30', '40']
# !!!Menu!!!
# 1)push
# 2)pop
# 3)last
# 4)Display
# 5)Exit
# Enter the Choice: 1
# Enter the Element: 50
# ['10', '20', '30', '40', '50']
# !!!Menu!!!
# 1)push
# 2)pop
# 3)last
# 4)Display
# 5)Exit
# Enter the Choice: 2
# 50
# ['10', '20', '30', '40']
# !!!Menu!!!
# 1)push
# 2)pop
# 3)last
# 4)Display
# 5)Exit
# Enter the Choice: 3
# 40
# !!!Menu!!!
# 1)push
# 2)pop
# 3)last
# 4)Display
# 5)Exit
# Enter the Choice: 4
# ELEMENT OF STACK : ['10', '20', '30', '40']
# !!!Menu!!!
# 1)push
# 2)pop
# ...

# %% [markdown]
# # Here are the steps for the Stack Operations Menu-Driven Program:

# %% [markdown]
#  Step 1: Display Menu
# - Print the menu options:
#     1. Push
#     2. Pop
#     3. Last
#     4. Display
#     5. Exit
#
#
# Step 2: Get User Choice
# - Prompt the user to enter their choice (1-5).
#
#
# Step 3: Perform Operation
# - Based on the user's choice, perform the corresponding operation:
#     - Push (1): Prompt the user to enter an element, append it to the stack, and print the updated stack.
#     - Pop (2): Check if the stack is empty. If not, remove and print the top element, and print the updated stack.
#     - Last (3): Print the top element of the stack.
#     - Display (4): Print all elements of the stack.
#     - Exit (5): Break the loop and exit the program.
#
#
# Step 4: Handle Invalid Choice
# - If the user enters an invalid choice, print an error message and prompt the user to enter a valid choice.
#
#
# Step 5: Repeat
# - Repeat steps 1-4 until the user chooses to exit the program.
