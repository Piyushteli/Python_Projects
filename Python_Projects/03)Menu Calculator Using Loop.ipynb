# %% [markdown]
# # "Menu Calculator Using Loop"

# %%
while True:
    print(f"\n!!!Menu!!!!\n 1.)Addition \n 2)Subraction \n 3)Multiplication \n 4)Division \n 5)power \n 0)exit")

    choice = int(input("Enter the choice: "))
    if (choice == 0):
        print("Good Bye")
        break

    if choice == 1 or choice <= 5:
        a = int(input("Enter the First number: "))
        b = int(input("Enter the second number: "))

        if choice == 1:
            print(f"addition={a + b}")

        elif choice == 2:
            print(f"subtraction={a - b}")

        elif choice == 3:
            print(f"Multiplication={a * b}")

        elif choice == 4:
            print(f"Division={a / b}")
        else:
            print(f"power={a ** b}")

    else:
        print("Invalid choice")
# Out:
# !!!Menu!!!!
#  1.)Addition
#  2)Subraction
#  3)Multiplication
#  4)Division
#  5)power
#  0)exit
# Enter the choice: 1
# Enter the First number: 20
# Enter the second number: 10
# addition=30
#
# !!!Menu!!!!
#  1.)Addition
#  2)Subraction
#  3)Multiplication
#  4)Division
#  5)power
#  0)exit
# Enter the choice: 2
# Enter the First number: 20
# Enter the second number: 10
# subtraction=10
#
# !!!Menu!!!!
#  1.)Addition
#  2)Subraction
#  3)Multiplication
#  4)Division
#  5)power
#  0)exit
# Enter the choice: 3
# Enter the First number: 10
# Enter the second number: 10
# Multiplication=100
#
# !!!Menu!!!!
#  1.)Addition
#  2)Subraction
#  3)Multiplication
#  4)Division
#  5)power
#  0)exit
# Enter the choice: 4
# Enter the First number: 10
# Enter the second number: 5
# Division=2.0
#
# !!!Menu!!!!
#  1.)Addition
#  2)Subraction
#  3)Multiplication
#  4)Division
#  5)power
#  0)exit
# Enter the choice: 5
# Enter the First number: 2
# Enter the second number: 3
# power=8
#
# ...

# %% [markdown]
# # Here are the steps for the Menu Calculator Using Loop:-

# %% [markdown]
# Step 1: Display Menu
# - Print the menu options:
#     1. Addition
#     2. Subtraction
#     3. Multiplication
#     4. Division
#     5. Power
#     6. Exit
#
#
# Step 2: Get User Choice
# - Prompt the user to enter their choice (0-5).
#
#
# Step 3: Handle Exit
# - If the user chooses to exit (0), print a goodbye message and break the loop.
#
#
# Step 4: Get Numbers
# - If the user chooses a mathematical operation (1-5), prompt them to enter two numbers.
#
#
# Step 5: Perform Operation
# - Based on the user's choice, perform the corresponding mathematical operation:
#     - Addition (1): a + b
#     - Subtraction (2): a - b
#     - Multiplication (3): a * b
#     - Division (4): a / b
#     - Power (5): a ** b
#
#
# Step 6: Display Result
# - Print the result of the mathematical operation.
#
#
# Step 7: Handle Invalid Choice
# - If the user enters an invalid choice, print an error message.
#
#
# Step 8: Repeat
# - Repeat steps 1-7 until the user chooses to exit the program.
